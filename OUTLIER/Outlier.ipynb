# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
sns.distplot(df['BloodPressure'])
# Out:
# C:\Users\DharanikumarK\AppData\Local\Temp\ipykernel_15568\52905997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BloodPressure'])
# <Axes: xlabel='BloodPressure', ylabel='Density'>

# %%
#Finding the Boundary Values
print("Highest allowed",df['BloodPressure'].mean() + 3*df['BloodPressure'].std())
print("Lowest allowed",df['BloodPressure'].mean() - 3*df['BloodPressure'].std())
# Out:
# Highest allowed 127.17289026193433
# Lowest allowed 11.038047238065673

# %%
# Finding the Outlier values
dfn=df[(df['BloodPressure'] > 127.172890) | (df['BloodPressure'] < 11.038047)]
dfn.shape
# Out:
# (35, 9)

# %%
dfn
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      115              0              0        0  35.3
# 15             7      100              0              0        0  30.0
# 49             7      105              0              0        0   0.0
# 60             2       84              0              0        0   0.0
# 78             0      131              0              0        0  43.2
# 81             2       74              0              0        0   0.0
# 172            2       87              0             23        0  28.9
# 193           11      135              0              0        0  52.3
# 222            7      119              0              0        0  25.2
# 261            3      141              0              0        0  30.0
# 266            0      138              0              0        0  36.3
# 269            2      146              0              0        0  27.5
# 300            0      167              0              0        0  32.3
# 332            1      180              0              0        0  43.3
# 336            0      117              0              0        0  33.8
# 347            3      116              0              0        0  23.5
# 357           13      129              0             30        0  39.9
# 426            0       94              0              0        0   0.0
# 430            2       99              0              0        0  22.2
# 435            0      141              0              0        0  42.4
# 453            2      119              0              0        0  19.6
# 468            8      120              0              0        0  30.0
# 484            0      145              0              0        0  44.2
# 494            3       80              0              0        0   0.0
# 522            6      114              0              0        0   0.0
# 533            6       91              0              0        0  29.8
# 535            4      132              0              0        0  32.9
# 589            0       73              0              0        0  21.1
# 601            6       96              0              0        0  23.7
# 604            4      183              0              0        0  28.4
# 619            0      119              0              0        0  32.4
# 643            4       90              0              0        0  28.0
# 697            0       99              0              0        0  25.0
# 703            2      129              0              0        0  38.5
# 706           10      115              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 7                       0.134   29        0
# 15                      0.484   32        1
# 49                      0.305   24        0
# 60                      0.304   21        0
# 78                      0.270   26        1
# 81                      0.102   22        0
# 172                     0.773   25        0
# 193                     0.578   40        1
# 222                     0.209   37        0
# 261                     0.761   27        1
# 266                     0.933   25        1
# 269                     0.240   28        1
# 300                     0.839   30        1
# 332                     0.282   41        1
# 336                     0.932   44        0
# 347                     0.187   23        0
# 357                     0.569   44        1
# 426                     0.256   25        0
# 430                     0.108   23        0
# 435                     0.205   29        1
# 453                     0.832   72        0
# 468                     0.183   38        1
# 484                     0.630   31        1
# 494                     0.174   22        0
# 522                     0.189   26        0
# 533                     0.501   31        0
# 535                     0.302   23        1
# 589                     0.342   25        0
# 601                     0.190   28        0
# 604                     0.212   36        1
# 619                     0.141   24        1
# 643                     0.610   31        0
# 697                     0.253   22        0
# 703                     0.304   41        0
# 706                     0.261   30        1

# %%
#Trimming of Outliers
new_df = df[(df['BloodPressure'] < 127.172890) & (df['BloodPressure'] > 11.038047)]
new_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [733 rows x 9 columns]

# %%
#fix limits
upper_limit = df['BloodPressure'].mean() + 3*df['BloodPressure'].std()
lower_limit = df['BloodPressure'].mean() - 3*df['BloodPressure'].std()
print(upper_limit,lower_limit)
# Out:
# 127.17289026193433 11.038047238065673

# %%
df['BloodPressure'] = np.where(df['BloodPressure']>upper_limit,upper_limit,df['BloodPressure'])

df['BloodPressure'] = np.where(df['BloodPressure']<lower_limit,lower_limit,df['BloodPressure'])

print((df['BloodPressure']).max())   # Below also same but writing code is different
# Out:
# 122.0

# %%
#apply capping
df['BloodPressure'] = np.where(
   df['BloodPressure']>upper_limit,
   upper_limit,
   np.where(
       df['BloodPressure']<lower_limit,
       lower_limit,
       df['BloodPressure']
   )
)
df.boxplot("BloodPressure")
# Out:
# <Axes: >

# %%
#Finding the IQR
percentile25 = df['BloodPressure'].quantile(0.25)
percentile75 = df['BloodPressure'].quantile(0.75)
iqr=percentile75 - percentile25
print(iqr)
print(percentile25)
print(percentile75)
# Out:
# 18.0
# 62.0
# 80.0

# %%
#Finding upper and lower limit
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)
# Out:
# 107.0
# 35.0

# %%
#Finding the IQR
percentile25 = df['Pregnancies'].quantile(0.25)
percentile75 = df['Pregnancies'].quantile(0.75)
iqr=percentile75 - percentile25
print(iqr)
print(percentile25)
print(percentile75)


#Finding upper and lower limit
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(upper_limit)
print(lower_limit)


#capping
new_df_cap = df.copy()
new_df_cap['Pregnancies'] = np.where(
   new_df_cap['Pregnancies'] > upper_limit,
   upper_limit,
   np.where(
       new_df_cap['Pregnancies'] < lower_limit,
       lower_limit,
       new_df_cap['Pregnancies']
   )
)
# Out:
# 5.0
# 1.0
# 6.0
# 13.5
# -6.5

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(df['Pregnancies'])
plt.subplot(2,2,2)
sns.boxplot(df['Pregnancies'])
plt.subplot(2,2,3)
sns.distplot(new_df_cap['Pregnancies'])
plt.subplot(2,2,4)
sns.boxplot(new_df_cap['Pregnancies'])
plt.show()
# Out:
# C:\Users\DharanikumarK\AppData\Local\Temp\ipykernel_15568\1373492005.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Pregnancies'])
# C:\Users\DharanikumarK\AppData\Local\Temp\ipykernel_15568\1373492005.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_cap['Pregnancies'])
